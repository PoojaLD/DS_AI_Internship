# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# Dataset
X = np.array([[1,2],[2,3],[3,3],[6,5],[7,7],[8,6]])
y = np.array(['Red','Red','Blue','Blue','Blue','Red'])

# New point
new_point = np.array([[3,2]])

# Try different k values
for k in [1, 2, 3, 4]:
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(X, y)
    
    prediction = model.predict(new_point)
    print(f"k={k} → Predicted Class:", prediction[0])
# Out:
# k=1 → Predicted Class: Blue
# k=2 → Predicted Class: Blue
# k=3 → Predicted Class: Red
# k=4 → Predicted Class: Blue
