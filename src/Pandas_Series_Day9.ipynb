# %%
#Task1 Pandas Series Practice

import pandas as pd

# Create a Series with custom labels
products = pd.Series(
    [700, 150, 300],
    index=["Laptop", "Mouse", "Keyboard"]
)

# Print full Series
print("Full Product Price List:")
print(products)

# Access price using label-based indexing
print("\nPrice of Laptop:")
print(products["Laptop"])

# Slice first two products using positional indexing
print("\nFirst Two Products:")
print(products.iloc[0:2])
# Out:
# Full Product Price List:
# Laptop      700
# Mouse       150
# Keyboard    300
# dtype: int64
#
# Price of Laptop:
# 700
#
# First Two Products:
# Laptop    700
# Mouse     150
# dtype: int64

# %%
#Task2 Handling Missing Values & Filtering

import pandas as pd

# Create Series with missing values
grades = pd.Series([85, None, 92, 45, None, 78, 55])

# Identify missing values
print("Missing Values (True means missing):")
print(grades.isnull())

# Fill missing values with 0
filled_grades = grades.fillna(0)

# Filter scores greater than 60
passed_students = filled_grades[filled_grades > 60]

# Print results
print("\nOriginal Grades:")
print(grades)

print("\nFilled Grades (NaN → 0):")
print(filled_grades)

print("\nScores greater than 60:")
print(passed_students)
# Out:
# Missing Values (True means missing):
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# dtype: bool
#
# Original Grades:
# 0    85.0
# 1     NaN
# 2    92.0
# 3    45.0
# 4     NaN
# 5    78.0
# 6    55.0
# dtype: float64
#
# Filled Grades (NaN → 0):
# 0    85.0
# 1     0.0
# 2    92.0
# 3    45.0
# 4     0.0
# 5    78.0
# 6    55.0
# dtype: float64
#
# Scores greater than 60:
# 0    85.0
# 2    92.0
# 5    78.0
# dtype: float64

# %%
#Task3 String Processing with .str

import pandas as pd

# Create Series of usernames
usernames = pd.Series([' Alice ', 'bOB', ' Charlie_Data ', 'daisy'])

# Clean the usernames
cleaned_usernames = usernames.str.strip().str.lower()

# Check which names contain letter 'a'
contains_a = cleaned_usernames.str.contains('a')

# Print results
print("Cleaned Usernames:")
print(cleaned_usernames)

print("\nContains letter 'a':")
print(contains_a)
# Out:
# Cleaned Usernames:
# 0           alice
# 1             bob
# 2    charlie_data
# 3           daisy
# dtype: object
#
# Contains letter 'a':
# 0     True
# 1    False
# 2     True
# 3     True
# dtype: bool
