# %%
# =====================================================
# MINI PROJECT 1 - COMPLETE EDA IN ONE FILE
# =====================================================

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("========== MINI PROJECT 1: EDA ==========")

# =====================================================
# PHASE 1: DETECTIVE WORK (DATASET CREATION & INSPECTION)
# =====================================================

print("\n--- PHASE 1: DATA INSPECTION ---")

# Create dataset
data = {
    "Student_ID": [1, 2, 3, 4, 5, 6, 7, 8],
    "Age": [20, 21, 20, 22, 21, None, 23, 20],
    "Gender": ["Female", "Male", "Female", "Female", "Male", "Male", None, "Female"],
    "Marks": [85, 78, 92, 88, None, 74, 90, 81],
    "Attendance": [90, 85, 95, 88, 80, None, 92, 87]
}

df = pd.DataFrame(data)

print("\nFirst 5 Rows:")
print(df.head())

print("\nDataset Info:")
print(df.info())

print("\nStatistical Summary:")
print(df.describe())

# =====================================================
# PHASE 2: DATA CLEANING
# =====================================================

print("\n--- PHASE 2: DATA CLEANING ---")

print("\nMissing Values:")
print(df.isnull().sum())

# Remove duplicates
df = df.drop_duplicates()

# Fill numeric missing values with median
for col in df.select_dtypes(include="number"):
    df[col] = df[col].fillna(df[col].median())

# Fill categorical missing values with mode
for col in df.select_dtypes(include="object"):
    df[col] = df[col].fillna(df[col].mode()[0])

print("\nMissing Values After Cleaning:")
print(df.isnull().sum())

print("\nData Cleaning Completed Successfully.")

# =====================================================
# PHASE 3: UNIVARIATE ANALYSIS
# =====================================================

print("\n--- PHASE 3: UNIVARIATE ANALYSIS ---")

df.hist(figsize=(10, 8))
plt.suptitle("Univariate Analysis (Histograms)")
plt.show()

print("Observation: Most students are aged 20-22 with generally high marks and attendance.")

# =====================================================
# PHASE 3: BIVARIATE ANALYSIS
# =====================================================

print("\n--- PHASE 3: BIVARIATE ANALYSIS ---")

sns.scatterplot(x="Attendance", y="Marks", data=df)
plt.title("Attendance vs Marks")
plt.show()

print("Observation: Higher attendance generally corresponds to higher marks.")

sns.boxplot(x="Gender", y="Marks", data=df)
plt.title("Marks Distribution by Gender")
plt.show()

print("Observation: Marks distribution between genders is fairly balanced.")

# =====================================================
# PHASE 4: MULTIVARIATE ANALYSIS
# =====================================================

print("\n--- PHASE 4: MULTIVARIATE ANALYSIS ---")

plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# =====================================================
# EXECUTIVE SUMMARY
# =====================================================

print("\n========== EXECUTIVE SUMMARY ==========")
print("1. Attendance shows strong positive correlation with Marks.")
print("2. Missing values were handled using median (numerical) and mode (categorical).")
print("3. Student performance is generally consistent with high attendance rates.")
print("\n========== EDA COMPLETED SUCCESSFULLY ==========")
# Out:
# ========== MINI PROJECT 1: EDA ==========
#
# --- PHASE 1: DATA INSPECTION ---
#
# First 5 Rows:
#    Student_ID   Age  Gender  Marks  Attendance
# 0           1  20.0  Female   85.0        90.0
# 1           2  21.0    Male   78.0        85.0
# 2           3  20.0  Female   92.0        95.0
# 3           4  22.0  Female   88.0        88.0
# 4           5  21.0    Male    NaN        80.0
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  8 non-null      int64
#  1   Age         7 non-null      float64
#  2   Gender      7 non-null      object
#  3   Marks       7 non-null      float64
#  4   Attendance  7 non-null      float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 452.0+ bytes
# None
#
# Statistical Summary:
#        Student_ID        Age      Marks  Attendance
# count     8.00000   7.000000   7.000000    7.000000
# mean      4.50000  21.000000  84.000000   88.142857
# std       2.44949   1.154701   6.608076    4.879500
# min       1.00000  20.000000  74.000000   80.000000
# 25%       2.75000  20.000000  79.500000   86.000000
# 50%       4.50000  21.000000  85.000000   88.000000
# 75%       6.25000  21.500000  89.000000   91.000000
# max       8.00000  23.000000  92.000000   95.000000
#
# --- PHASE 2: DATA CLEANING ---
#
# Missing Values:
# Student_ID    0
# Age           1
# Gender        1
# Marks         1
# Attendance    1
# dtype: int64
#
# Missing Values After Cleaning:
# Student_ID    0
# Age           0
# Gender        0
# Marks         0
# Attendance    0
# dtype: int64
#
# Data Cleaning Completed Successfully.
#
# --- PHASE 3: UNIVARIATE ANALYSIS ---
# Observation: Most students are aged 20-22 with generally high marks and attendance.
#
# --- PHASE 3: BIVARIATE ANALYSIS ---
# Observation: Higher attendance generally corresponds to higher marks.
# Observation: Marks distribution between genders is fairly balanced.
#
# --- PHASE 4: MULTIVARIATE ANALYSIS ---
# ========== EXECUTIVE SUMMARY ==========
# 1. Attendance shows strong positive correlation with Marks.
# 2. Missing values were handled using median (numerical) and mode (categorical).
# 3. Student performance is generally consistent with high attendance rates.
#
# ========== EDA COMPLETED SUCCESSFULLY ==========
